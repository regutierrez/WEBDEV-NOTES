# %% [markdown]
# # [The Complete 2022 Web Developer Bootcamp](https://www.udemy.com/course/the-complete-web-development-bootcamp/)
# ---
# ## Useful Links
# - https://devdocs.io/
# - codepen.io
# - web.archive.org
# - unicode-table.com
# - developer.mozilla.org

# %% [markdown]
# # HTML
# ---

# %% [markdown]
# ## HTML Boilerplate

# %%
<!DOCTYPE html> <!--tells the browser to render this file as html-->
<html lang="en">
<head> <!--holds info about the webpage. tells the browser how to handle the webpage-->
    <meta charset="UTF-8"> <!--meta: gives extra information(metadata) about the file;-->
    <!--charset: UTF-8 encoding. may certain sets of characters na pwedeng irender per charset-->
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1.0"> <!--this meta element ensures na optimized ang webpage mo for different screen sizes-->
    <!--meta tags are used by search engines. check MDN docs on this-->
    
    <title>Pael</title>
</head>
<body>
    
</body>
</html>

# %% [markdown]
# ## Notes
#
# - Use <strong>  instead of <b>, and <em> instead of <i>, to make meaning apart from the styling change
# - the alt attribute helps search engines to index your webpage/contents from yout webpage
# - Though pwede mong i-style yung mga elements mo sa HTML, pero hindi siya advisable dahil all styles should be in the CSS file
# - for adding/accepting inputs in HTML, check the forms documentation in MDN
# - you can specify the encoding type of forms using enctype. May mga instances na nagkakaroon ng random characters  if you did not specify the the encoding type.

# %% [markdown]
# ## HTML forms (FCC)
# As this is a quiz, you will need a form for users to submit answers. You can semantically separate the content within the form using section elements.
#
# Within the main element, create a form with three nested section elements. Then, make the form submit to https://freecodecamp.org/practice-project/accessibility-quiz, using the correct method.
#
# ~~~html
#     <main>
#       <form action="https://freecodecamp.org/practice-project/accessibility-quiz" method="post">
#         <section></section>
#         <section></section>
#         <section></section>
#         <button type="submit" id="submit">Submit</button>
#       </form>
#     </main>
# ~~~
#
# Keeping in mind best-practices for form inputs, give each `input` an appropriate `type` and `name` attribute. Placing a placeholder is not a best-practice for accessiblity; to often, users confuse the placeholder text with an actual input value-- they think there is already a value in the input.
#
# There is a common pattern to visually hide text for only screen readers to read.
# This pattern is to set the following CSS properties:
# ~~~css
# position: absolute;
# width: 1px;
# height: 1px;
# padding: 0;
# margin: -1px;
# overflow: hidden;
# clip: rect(0, 0, 0, 0);
# white-space: nowrap;
# border: 0;
# ~~~
#
# Two final semantic HTML elements for this project are the `footer` and `address` elements. The `footer` element is a container for a collection of content that is related to the page, and the `address` element is a container for contact information for the author of the page.
#
# ## [HTML Best Practices](https://github.com/hail2u/html-best-practices)

# %% [markdown]
# # CSS
# ---

# %% [markdown]
# ## Hierarchy of CSS (From most important)
# - Inline CSS
# - Internal CSS
# - External CSS

# %% [markdown]
# ## CSS Syntax

# %% [markdown]
# ~~~css
# selector{property:value;}
# /* this is a comment */
# /*
# selector: yan yung element/header na sstyle-an mo
# property: yan yung property nung selector na gusto mong i-style
# value: kung ano mismo yung itsura na gusto mo
# */
#
# /*CLASS SELECTOR*/
# .name_of_class {
#     background-color: green;
# }
#
# /*ID SELECTOR*/
# #name_of_id{
#     color: blue;
# }
# ~~~

# %% [markdown]
# ## ID and CLASSES
# ---
# may mga instances na iba iba ang gusto mong style ng mga h1 mo.
# pwede ka mag assign ng class or ID sa iba't ibang html elements mo for granularity
#
# Yung ID selector hindi yan nagagamit nang paulit ulit sa isang page
# EX: HINDI TO PWEDE
#
# ~~~html
# <h1 id="test">
#
# <p id="test">
# ~~~
#
# PERO PWEDE TO
# ~~~html
# <h1 id="test">
#
# <p id="paragraph-1">
# ~~~
#
#
# Ginagamit lang tong ID kapag may **exactly one element** lang per page.
# (Page titles, Page heading, navigation bar, etc)
#
# Yung class, pwede mong gamitin sa maraming elements. So advisable siya sa mga related elements
# na gusto mo parehas ang itsura.
#
# kung alin yung mas specific na style, yun yung susundin. So mas mataas sa hierarchy si ID,
# then class, then yung selector mo
#
# ### For Classes
# Pwede ka mag assign ng **more than 1** class sa isang element mo.
# EX:
# ~~~html
# <img class="brocoli circular" src="...">
# ~~~
#
# ~~~css
# /*CLASS SELECTOR*/
# .brocolli{
#     background-color: red;
# }
#
# .circular{
#     border-radius: 100%
# }
# ~~~
#
# **Hindi** mo to magagawa with ID
#
# ### The element`[class~="class-name"]`
# The span[class~="sr-only"] selector will select any span element whose class includes sr-only.
#
#
# ## THERE ARE OTHER CSS SELECTORS. CHECK IT [HERE](https://www.geeksforgeeks.org/selectors-in-css/)

# %% [markdown]
# ## PSEUDO CLASSES
# ---
# Ito yung mga nagsstart sa **':'**
# WIth these classes, pwede mong mabago yung itsura nila based on their **states**
# Example of state is: **hover** (kapag nakahover yung mouse mo sa element)
#
# ~~~css
# img :hover{
#     background-color: red;
# }
# ~~~
# Ibig sabihin nito, magbabago yung background color to red kapag nag-hover ka sa **kahit anong img tag element** sa page mo

# %% [markdown]
# ## The Box Model of Website Styling
# ---
# We can alter the width and height of a div. Pag ginawa mo yun, mapu-push yung div na katabi niya or div na nasa baba niya
#
# ###### Others
#  Border - pag naglagay ka nito, additional kapal siya sa element mo. Kung nagset ka ng:
#  ~~~css
#  {border:solid;}
#  ~~~
#  ...and expected na 300px yung mismong element mo, yung border ay additional *kapal* dun sa 300px na yun. So for example:
#  ~~~css
#  {border-width:50px;}
#  ~~~
#  Ibig sabihin, yung total *kapal* ng element ay 300px + 50px sa left/right and 50px sa top/bottom
#
# Padding - naglalagay ka ng allowance between the content(text,etc) at yung edge ng element niya
#
#
# Yung Margin - siya yung naglalagay ng buffer zone between elements outside the border(kung nagset ka ng border)
#
# Itong tatlong to ay makikita mo lagi sa dev tools > elements > styles

# %% [markdown]
# ## CSS Display Properties
# ---
# - block
# - inline
# - inline-block
# - none
#
# Kapag may gusto kang i-edit pero same line, pwede kang gumamit ng <span> element! <span> is an inline element! Parehas siya sa <img>!
#
# Pero pwede mo ring i-convert to inline display yung ibang mga elements, pero ang tradeoff ay hindi mo magagawa yung mga bagay na hindi mo rin magagawa sa native **inline** elements (like palitan yung width and shit)
#  ~~~css
#  p{
#     display: inline;
#     width:100px;
#     /*si p ay naturally a block element, pero pwede i-convert to inline, but you'll lose abilities like width adjustment*/
#  }
#  ~~~
#
#
# Pwede ring the other way around: Si **inline** element ay gagawin mong **block** element naman. And it will also gain *skills* that any block element can do (like change width)
#  ~~~css
#  span{
#     display: block;
#     width: 100px
#     /*si span ay naturally an inline element, pero pwede i-convert to block. Hindi na siya magkatabi sa isang linya, pero pwede mo nang i-adjust yung width, for instance
#     */
#  }
#  ~~~
#
#
#  Kung gusto mo naman ng best of both worlds ng inline and block, pwede mong gamitin yung display property na **inline-block**
#  ~~~css
#  p{
#     display: inline-block;
#     width:100px;
#     /*ngayon, pwede nang magtabi ng other elements kay p on the same line, pero pwede na ring i-edit yung width niya*/
#  }
#  ~~~
#
# Yung display: **none;**, parang hinide mo lang yung element. Pwede mo ring gamitin yung visibility: **hidden;**. With this, hinide mo yung content nung element, pero magtetake parin siya ng space.
#
# ## Take note of this:
# - In html, child (nested) elements sit on parent elements
#
# ## CSS Positioning
# ---
# - static - ifa-follow lang kung ano yung usual rules ni html
# - relative - position element relative to the usual position based on the html rules
# EX:
#  ~~~css
#  .red-box{
#     position: relative;
#     right: 10px; /*adds a 'margin' on the right side (mapupush yung element mo to the left)*/
#     left: 10 px; /*adds a 'margin' on the left side (mapupush yung element mo to the right)*/
#     top: 10 px; /*adds a 'margin' on the top side (mapupush yung element mo to the bottom)*/
#     bottom: 10 px; /*adds a 'margin' on the bot side (mapupush yung element mo to the top)*/
#  }
#  ~~~
#  *NOTE:kapag ginamit mo to, hindi niya ipu-push yung mga katabi niyang elements, kakainin niya yung space instead*
#
# - position: absolute - position element relative to its **parent**.
# - position: fixed - magsstay siya sa screen kahit magscroll up or down ka

# %% [markdown]
# ### Centering CSS Elements
# - you can center align your whole body by appending the following to your body element:
# ~~~css
# text-align:auto;
# ~~~
#
# Pag nagdagdag ka ng width attribute sa mga child elements ni body, hindi na siya mase-center.
# Pwede mo siyang ayusin ulit by using:
# ~~~css
# margin: auto;
# ~~~

# %% [markdown]
# ## Font Sizes
# - Dynamic - yung font-size: 100% is equal to 16px. You can also use em
# Notes:
# - 1 em = 16 px = 100%
# - kapag dynamic values ang gamit mo, pwede siyang magpatong patong.EX: Si <p> ay child ni <body>
#  ~~~css
#  body{
#     font-size: 2 em;
#  }
#
#  p{
#     font-size: 4 em;
#  }
#  /*yung font size ngayon ng <p> ay magiging 2*4 = 8em!
#  ~~~
#  *this is not the case with static font-size. kung ano yung sinet mong font size sa <p> mo, yun yung lalabas kahit ano pang ilagay mo sa parent element ni <p>*
#  *you can also use **rem** instead of em. Para maiwasan yung pagpatong patong ng mga font sizes*

# %% [markdown]
# ## CSS FLEXBOX (FCC)
#
#
# ### Flexbox
# Flexbox is a one-dimensional CSS layout that can control the way items are spaced out and aligned within a container.
#
# To use it, give an element a display property of flex. This will make the element a flex container. Any direct children of a flex container are called flex items.
#
# Flexbox has a main and cross axis. The main axis is defined by the flex-direction property, which has four possible values:
#
# * row (default): horizontal axis with flex items from left to right
# * row-reverse: horizontal axis with flex items from right to left
# * column: vertical axis with flex items from top to bottom
# * column-reverse: vertical axis with flex items from bottom to top
#
# > Note: The axes and directions will be different depending on the text direction. The values shown are for a left-to-right text direction.
#
# ### box-sizing: border-box
# If you inspect your .label element with your browser's developer tools, you may notice that it's actually 288 pixels wide instead of 270. This is because, by default, the browser includes the border and padding when determining an element's size.
#
# To solve this, reset the box model by creating a * selector and giving it a box-sizing property of border-box.
#
# ### flex-wrap
# The flex-wrap property determines how your flex items behave when the flex container is too small. Setting it to wrap will allow the items to wrap to the next row or column. nowrap (default) will prevent your items from wrapping and shrink them if needed.
#
# ### align-items
# The align-items property positions the flex content along the cross axis. In this case, with your flex-direction set to row, your cross axis would be vertical.
#
# ### justify-content
# The justify-content property determines how the items inside a flex container are positioned along the main axis, affecting their position and the space around them.
#
# ### object-fit
# Notice how some of your images have become distorted. This is because the images have different aspect ratios. Rather than setting each aspect ratio individually, you can use the `object-fit` property to determine how images should behave.
#
# You can use `object-fit: cover` to tell the image to fill the img container while maintaining the aspect ratio, resulting in cropping to fit.
#
# ### gap
# The gap CSS shorthand property sets the gaps, also knowns as gutters, between rows and columns. The gap property and its row-gap and column-gap sub-properties provide this functionality for flex, grid, and multi-column layout. You apply the property to the container element.
#
# ### ::after
# The ::after pseudo-element creates an element that is the last child of the selected element. You can use it to add an empty element after the last image. If you give it the same width as the images it will push the last image to the left when the gallery is in a two-column layout. Right now, it is in the center because you set justify-content: center on the flex container.
#
# Example:
# ~~~css
# .container::after {
#   content: "";
#   width: 860px;
# }
# ~~~
#
# ### calc
# The calc() function is a CSS function that allows you to calculate a value based on other values. For example, you can use it to calculate the width of the viewport minus the margin of an element:
#
# ~~~css
# .example {
#   margin: 10px;
#   width: calc(100% - 20px);
# }
# ~~~

# %% [markdown]
# ## Typography
#
# ### letter-spacing
# The letter-spacing property can be used to adjust the space between each character of text in an element.
#
# ### overflow
# The larger font size of the number 230 is causing it to overflow. Give the .calories-info h1 an overflow property set to hidden to avoid this.
#
# ### clear
# Give the .divider selector a clear property set to right. This will clear the float property, pushing the divider and any following content down below the float text.
#
# ### :not
# The :not pseudo-selector can be used to select all elements that do not match the given CSS rule.
# ~~~css
# div:not(#example) {
#   color: red;
# }
# ~~~
# The above selects all div elements without an id of example.
#
# ### remove underlines and other shits from text
# use `text-decoration: none;`

# %% [markdown]
# ## Accessiblity
#
# ### meta viewport
# Continuing with the meta elements, a viewport definition tells the browser how to render the page. Including one betters visual accessibility on mobile, and improves SEO (search engine optimization).
#
# ### role attribute
# To increase the page accessibility, the role attribute can be used to indicate the purpose behind an element on the page to assistive technologies. The role attribute is a part of the Web Accessibility Initiative (WAI), and accepts preset values.
# ```<section role="region"></section>```
#
# Every region role requires a visible label, which should be referenced by the aria-labelledby attribute.
# To the section elements, give the following aria-labelledby attributes:
# - student-info
# - html-questions
# - css-questions
#
# Then, within each section element, nest one h2 element with an id matching the corresponding aria-labelledby attribute. Give each h2 suitable text content.
# ~~~html
# <form method="post" action="https://freecodecamp.org/practice-project/accessibility-quiz">
#     <section role="region" aria-labelledby="student-info">
#         <h2 id="student-info">Student Info</h2>
#     </section>
#
#     <section role="region" aria-labelledby="html-questions">
#         <h2 id="html-questions">HTML Questions</h2>
#     </section>
#     <section role="region" aria-labelledby="css-questions">
#         <h2 id="css-questions">CSS Questions</h2>
#     </section>
# </form>
# ~~~
#
# ### Adding href that will redirect to page
# To be able to navigate within the page, give each anchor element an href corresponding to the id of the h2 elements.
# ~~~html
# <ul>
#     <li><a href="#student-info">INFO</a></li>
#     <li><a href="#html-questions">HTML</a></li>
#     <li><a href="#css-questions">CSS</a></li>
# </ul>
# ~~~
#
# ### Contrast
# On the topic of visual accessibility, contrast between elements is a key factor. For example, the contrast between the text and the background of a heading should be at least 4.5:1.
# Try this [website](https://webaim.org/resources/contrastchecker/)
#
#
# ### cursor (CSS)
# https://www.w3schools.com/cssref/tryit.php?filename=trycss_cursor
#
# ### scroll-behavior
# Clicking on the navigation links should jump the viewport to the relevant section. However, this jumping can be disorienting for some users.
#
# Select all elements, and set the scroll-behavior to smooth.
#
# ### shortcut key
# Finally, the navigation accessibility can be improved by providing keyboard shortcuts.
#
# The accesskey attribute accepts a space-separated list of access keys. For example:
#
# `<button type="submit" accesskey="s">Submit</button>`
#
# Give each of the navigation links a single-letter access key.
#
# Note: It is not always advised to use access keys, but they can be useful

# %% [markdown]
# ## Pseudo Selectors
#
# ### Tables and caption element
# HTML tables use the caption element to describe what the table is about. The caption element should always be the first child of a table, but can be positioned with the caption-side CSS property.
#
# ### [clip](https://developer.mozilla.org/en-US/docs/Web/CSS/clip-path#:~:text=The%20clip%2Dpath%20CSS%20property,while%20those%20outside%20are%20hidden.)
# The CSS clip property is used to define the visible portions of an element.
# The clip-path property determines the shape the clip property should take.
#
# ### prevent from overflowing
# To prevent the text content from overflowing, give your `span[class~="sr-only"]` selector an overflow property set to hidden and a white-space property set to nowrap.
#
# ### :not()
# The :not() pseudo-selector is used to target all elements that do not match the selector - in this case, any of your span elements that do not have the sr-only class. This ensures that your earlier rules for the span[class~="sr-only"] selector are not overwritten.
#
# ### !important
# Rather than having to constantly double-check you are not overwriting your earlier properties, you can use the !important keyword to ensure these properties are always applied, regardless of order or specificity.
# ~~~css
# element {
#     border: 0 !important;
# }
# ~~~
#
# ### inherit property and ::before and ::after pseudo-elements
# Now that you have reset the html box model, you need to pass that on to the elements within as well. To do this, you can set the box-sizing property to inherit, which will tell the targeted elements to use the same value as the parent element.
#
# You will also need to target the pseudo-elements, which are special keywords that follow a selector. The two pseudo-elements you will be using are the ::before and ::after pseudo-elements.
#
# The ::before selector creates a pseudo-element which is the first child of the selected element, while the ::after selector creates a pseudo-element which is the last child of the selected element. These pseudo-elements are often used to create cosmetic content, which you will see later in this project.
#
#
# ### content property
# The content property is used to set or override the content of the element. By default, the pseudo-elements created by the ::before and ::after pseudo-selectors are empty, and the elements will not be rendered to the page. Setting the content property to an empty string "" will ensure the element is rendered to the page while still being empty.
#
# ## Responsive Design
#
# ### @media
# The @media at-rule, also known as a media query, is used to conditionally apply CSS. Media queries are commonly used to apply CSS based on the viewport width using the max-width and min-width properties.
#
# In the below example the padding is applied to the .card class when the viewport is 960px wide and below.
# ~~~css
# @media (max-width: 960px) {
#   .card {
#     padding: 2rem;
#   }
# }
#
# /*you can also use logical operators dyan sa @media*/
# @media (min-width: 500px) and (max-width: 1000px){
#
# }
# ~~~
